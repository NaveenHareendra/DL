# %% [markdown]
# # Task 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#1.	Create a random 4x4 array from an exponential distribution. Refer numpy functions

x=np.random.rand(4,4)

# %%
x.shape
# Out:
# (4, 4)

# %%
plt.hist(np.random.rand(100000), density=True, bins=100, histtype="step", color="blue", label="rand")
plt.hist(np.random.randn(100000), density=True, bins=100, histtype="step", color="red", label="randn")
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc = "upper left")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
x = np.linspace(-2, 2, 500)
y = x**2

plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.title("Square function")
plt.xlabel("x")
plt.ylabel("y = x**2")
plt.grid(True)
plt.show()

# %%
import seaborn as sns


# Pandas for managing datasets
import pandas as pd

# %%
# Read dataset
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

# %%
     


# Display first 5 observations
df.head()
     


# Preprocess DataFrame
stats_df = df.drop(['Total', 'Stage', 'Legendary'], axis=1)

# %%
# Calculate correlations
corr = stats_df.corr()
 
corr
# Out:
#                HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# HP       1.000000  0.306768  0.119782  0.236649  0.490978 -0.040939
# Attack   0.306768  1.000000  0.491965  0.146312  0.369069  0.194701
# Defense  0.119782  0.491965  1.000000  0.187569  0.139912 -0.053252
# Sp. Atk  0.236649  0.146312  0.187569  1.000000  0.522907  0.411516
# Sp. Def  0.490978  0.369069  0.139912  0.522907  1.000000  0.392656
# Speed   -0.040939  0.194701 -0.053252  0.411516  0.392656  1.000000

# %%
# Heatmap
plt.figure(figsize=(9,8))
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Task 2

# %%
# Create the pandas DataFrame with column name is provided explicitly


# Read dataset
df = pd.read_csv('Au_nanoparticle_dataset.csv', index_col=0, encoding='latin')
     
newAU_Df = df.drop(['N_total', 'N_bulk', 'N_surface', 'R_avg'], axis=1)
 
newAU_Df
# Out:
#         T       tau  time        Volume    R_min    R_max   R_diff   R_std  \
# ID
# 1     273  0.000025     1  2.710000e-26  15.5898  19.4516   3.8618  0.6230
# 2     273  0.000025     2  2.780000e-26  15.3996  24.1755   8.7760  0.9295
# 3     273  0.000025     3  7.850000e-26  21.9199  31.0305   9.1106  1.0701
# 4     273  0.000025     4  1.220000e-25  23.2542  37.8795  14.6253  2.3732
# 5     273  0.000025     5  1.860000e-25  27.1200  39.7614  12.6415  1.9397
# ...   ...       ...   ...           ...      ...      ...      ...     ...
# 3996  973  0.000250     6  2.550000e-26  13.8048  23.1729   9.3681  1.5120
# 3997  973  0.000250     7  3.920000e-26  12.0020  36.7573  24.7553  4.8536
# 3998  973  0.000250     8  4.680000e-26  18.8611  24.6101   5.7490  1.0829
# 3999  973  0.000250     9  5.330000e-26  18.7624  26.0008   7.2385  1.2556
# 4000  973  0.000250    10  6.750000e-26  19.1334  44.7678  25.6344  5.0678
#
# ...

# %%
df.head(20)
# Out:
#       T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# ID
# 1   273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 2   273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 3   273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 4   273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 5   273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
# 6   273  0.000025     6    13375   10768       2607  2.260000e-25  33.2496
# 7   273  0.000025     7    13795   11155       2640  2.340000e-25  33.6164
# 8   273  0.000025     8    13947   11304       2643  2.360000e-25  34.5185
# 9   273  0.000025     9    14020   11357       2663  2.370000e-25  34.7525
# 10  273  0.000025    10    14056   11389       2667  2.380000e-25  34.7870
# 11  273  0.000050     1     1534     966        568  2.600000e-26  15.0408
# ...

# %%
new_df = pd.read_csv('Au_nanoparticle_dataset.csv', index_col=0, encoding='latin')
     
new_df1=new_df[['N_total', 'N_bulk', 'N_surface', 'R_avg']]

N_total_mean = df["N_total"].mean()
N_bulk_mean = df["N_bulk"].mean()
R_avg_mean = df["R_avg"].mean()
N_surface_mean = df["N_surface"].mean()

# %%
N_total_std = df["N_total"].std()
N_bulk_std = df["N_bulk"].std()
R_avg_std = df["R_avg"].std()
N_surface_std = df["N_surface"].std()

# %%
df['N_total'].quantile([0.25, 0.5, 0.75])
df['N_bulk'].quantile([0.25, 0.5, 0.75])
df['R_avg'].quantile([0.25, 0.5, 0.75])
df['N_surface'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     437.00
# 0.50     666.00
# 0.75    1301.75
# Name: N_surface, dtype: float64

# %%
g = sns.PairGrid(new_df1)
g.map_upper(sns.histplot) #bivariate histogram
g.map_diag(sns.histplot) 
g.map_lower(sns.kdeplot)
